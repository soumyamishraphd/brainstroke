# %%
import pandas as pd
from lazypredict.Supervised import LazyClassifier, LazyRegressor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_excel('usefile.xlsx')

# %%
df
# Out:
#        Gender Index   Age  Hypertension  Heart Disease  Martial Status  \
# 0                 0  3.00             0              0               0
# 1                 0 58.00             1              0               1
# 2                 1  8.00             0              0               0
# 3                 1 70.00             0              0               1
# 4                 1 47.00             0              0               1
# ...             ...   ...           ...            ...             ...
# 43395             1 10.00             0              0               0
# 43396             1 56.00             0              0               1
# 43397             1 82.00             1              0               1
# 43398             0 40.00             0              0               1
# 43399             1 82.00             0              0               1
#
#        Work Type Index  Residence Type  Average Glucose Level   BMI  \
# 0                    0               0                  95.12 18.00
# 1                    2               1                  87.96 39.20
# 2                    2               1                 110.89 17.60
# 3                    2               0                  69.04 35.90
# 4                    2               1                 210.95 50.10
# ...                ...             ...                    ...   ...
# 43395                0               1                  58.64 20.40
# 43396                4               1                 213.61 55.40
# 43397                2               1                  91.94 28.90
# 43398                2               1                  99.16 33.20
# 43399                2               1                  79.48 20.60
#
#        Smoking Status Index  Stroke
# 0                         0       0
# 1                         0       0
# 2                         0       0
# 3                         1       0
# 4                         0       0
# ...                     ...     ...
# 43395                     0       0
# 43396                     1       0
# 43397                     1       0
# 43398                     0       0
# 43399                     0       0
#
# [43400 rows x 11 columns]

# %%
X = df.drop('Stroke',axis=1)
y = df['Stroke']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y,test_size=.5,random_state =123)

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(x_train, x_test, y_train, y_test)
# Out:
# 100%|██████████| 29/29 [05:53<00:00, 12.17s/it]

# %%
print(models)
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.76               0.73     0.73      0.85
# GaussianNB                         0.90               0.65     0.65      0.93
# QuadraticDiscriminantAnalysis      0.92               0.64     0.64      0.94
# DecisionTreeClassifier             0.96               0.54     0.54      0.97
# ExtraTreeClassifier                0.97               0.53     0.53      0.97
# PassiveAggressiveClassifier        0.97               0.52     0.52      0.97
# LinearDiscriminantAnalysis         0.98               0.52     0.52      0.97
# LabelSpreading                     0.97               0.52     0.52      0.97
# LabelPropagation                   0.97               0.52     0.52      0.97
# BernoulliNB                        0.98               0.52     0.52      0.97
# KNeighborsClassifier               0.98               0.50     0.50      0.97
# BaggingClassifier                  0.98               0.50     0.50      0.97
# XGBClassifier                      0.98               0.50     0.50      0.97
# ExtraTreesClassifier               0.98               0.50     0.50      0.97
# LGBMClassifier                     0.98               0.50     0.50      0.97
# RidgeClassifier                    0.98               0.50     0.50      0.97
# SGDClassifier                      0.98               0.50     0.50      0.97
# SVC                                0.98               0.50     0.50      0.97
# RidgeClassifierCV                  0.98               0.50     0.50      0.97
# LinearSVC                          0.98               0.50     0.50      0.97
# Perceptron                         0.98               0.50     0.50      0.97
# LogisticRegression                 0.98               0.50     0.50      0.97
# DummyClassifier                    0.98               0.50     0.50      0.97
# CalibratedClassifierCV             0.98               0.50     0.50      0.97
# RandomForestClassifier             0.98               0.50     0.50      0.97
# AdaBoostClassifier                 0.98               0.50     0.50      0.97
#
#                                Time Taken
# Model
# NearestCentroid                      0.13
# GaussianNB                           0.07
# QuadraticDiscriminantAnalysis        0.19
# DecisionTreeClassifier               0.10
# ExtraTreeClassifier                  0.09
# PassiveAggressiveClassifier          0.15
# LinearDiscriminantAnalysis           0.38
# LabelSpreading                     177.28
# LabelPropagation                   139.47
# BernoulliNB                          0.06
# KNeighborsClassifier                 3.35
# BaggingClassifier                    0.64
# XGBClassifier                        3.24
# ExtraTreesClassifier                 1.62
# LGBMClassifier                       3.08
# RidgeClassifier                      0.14
# SGDClassifier                        0.15
# SVC                                  9.91
# RidgeClassifierCV                    0.19
# LinearSVC                            2.47
# Perceptron                           0.11
# LogisticRegression                   0.21
# DummyClassifier                      0.06
# CalibratedClassifierCV               5.50
# RandomForestClassifier               3.02
# AdaBoostClassifier                   1.05
